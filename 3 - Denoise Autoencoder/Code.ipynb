# %% [markdown]
# # Denoise Autoencoder

# %%
# import libs
import numpy as np
from keras.datasets import mnist

# %%
(X_train , _) ,(X_test, _) = mnist.load_data()
X_train.shape
# Out:
# (60000, 28, 28)

# %%
from matplotlib import pyplot as plt
fig, axes = plt.subplots(2,10, figsize = (16, 4))

count = 0

for i in range(2):
    for j in range(10):
        axes[i,j].imshow(X_train[count], cmap = 'gray')
        count+=1

# %% [markdown]
# ## Normalize

# %%
X_train = X_train / 255.0
X_test = X_test / 255.0

# %% [markdown]
# ## Add noise to images

# %%
# prepare source data
noise_factor = 0.1

X_train_noise = X_train + noise_factor * np.random.normal(loc = 0., scale = 1., size = X_train.shape)
X_test_noise = X_test + noise_factor * np.random.normal(loc = 0., scale = 1., size = X_test.shape)

# %%
X_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# ## Visualize noisy data

# %%
fig, axes = plt.subplots(2,10, figsize = (16,4))

count = 0
for i in range(2):
    for j in range(10):
        axes[i,j].imshow(X_train_noise[count], cmap = 'gray')
        count+=1

# %% [markdown]
# # Reshape dataset

# %%
X_train = X_train.reshape(X_train.shape[0], 28 ,28, 1)
X_test = X_test.reshape(X_test.shape[0], 28,28,1)

X_train_noise = X_train_noise.reshape(X_train_noise.shape[0], 28 ,28, 1)
X_test_noise = X_test_noise.reshape(X_test_noise.shape[0], 28,28,1)

X_train.shape, X_train_noise.shape
# Out:
# ((60000, 28, 28, 1), (60000, 28, 28, 1))

# %% [markdown]
# ## Model

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPool2D, Dense, UpSampling2D, BatchNormalization
from keras.callbacks import ModelCheckpoint

import tensorflow as tf

# %%
devices = tf.config.experimental.list_physical_devices("GPU")
tf.config.experimental.set_memory_growth(devices[0], enable = True)

# %%
# encoder
encoder_input = Input(shape = X_train.shape[1:])
x = Conv2D(32, (3,3), activation = 'relu', padding = 'same')(encoder_input)
x = BatchNormalization()(x)
x = MaxPool2D(pool_size = (2,2), padding = 'same')(x)
x = Conv2D(32, (3,3), activation = 'relu', padding = 'same')(x)
x = BatchNormalization()(x)
encoded = MaxPool2D(pool_size = (2,2), padding = 'same')(x)

# %%
# decoder
x = Conv2D(32, (3,3), activation = 'relu', padding = 'same')(encoded)
x = BatchNormalization()(x)
x = UpSampling2D()(x)
x = Conv2D(32, (3,3), activation = 'relu', padding = 'same')(x)
x = BatchNormalization()(x)
x = UpSampling2D()(x)
decoded = Conv2D(1, (3,3), activation = 'sigmoid', padding = 'same')(x)

# %%
autoencoder = Model(encoder_input, decoded, name = 'Denoising_Model')
autoencoder.summary()
# Out:
# Model: "Denoising_Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 14, 14, 32)        128
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 32)          9248
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 7, 7, 32)          128
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 14, 14, 32)        128
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 1)         289
# =================================================================
# Total params: 28,865
# Trainable params: 28,609
# Non-trainable params: 256
# _________________________________________________________________

# %%
autoencoder.compile(loss = 'binary_crossentropy', optimizer = 'adam')

# %% [markdown]
# # Train the model

# %%
checkpoint = ModelCheckpoint("denoising_model.h5", save_best_only=True, save_weights_only=False, verbose = 1)
history = autoencoder.fit(X_train_noise, X_train, batch_size = 128, epochs = 50, callbacks = checkpoint, validation_split = 0.25, verbose = 2)
# Out:
# Epoch 1/50
#
# Epoch 00001: val_loss improved from inf to 0.13133, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.1585 - val_loss: 0.1313
# Epoch 2/50
#
# Epoch 00002: val_loss improved from 0.13133 to 0.07565, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0762 - val_loss: 0.0756
# Epoch 3/50
#
# Epoch 00003: val_loss did not improve from 0.07565
# 352/352 - 3s - loss: 0.0733 - val_loss: 0.0764
# Epoch 4/50
#
# Epoch 00004: val_loss improved from 0.07565 to 0.07197, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0718 - val_loss: 0.0720
# Epoch 5/50
#
# Epoch 00005: val_loss did not improve from 0.07197
# 352/352 - 3s - loss: 0.0710 - val_loss: 0.0728
# Epoch 6/50
#
# Epoch 00006: val_loss improved from 0.07197 to 0.07053, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0704 - val_loss: 0.0705
# Epoch 7/50
#
# Epoch 00007: val_loss improved from 0.07053 to 0.07004, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0700 - val_loss: 0.0700
# Epoch 8/50
#
# Epoch 00008: val_loss improved from 0.07004 to 0.06985, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0695 - val_loss: 0.0698
# Epoch 9/50
#
# Epoch 00009: val_loss improved from 0.06985 to 0.06957, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0691 - val_loss: 0.0696
# Epoch 10/50
#
# Epoch 00010: val_loss improved from 0.06957 to 0.06916, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0690 - val_loss: 0.0692
# Epoch 11/50
#
# Epoch 00011: val_loss did not improve from 0.06916
# 352/352 - 3s - loss: 0.0687 - val_loss: 0.0705
# Epoch 12/50
#
# Epoch 00012: val_loss improved from 0.06916 to 0.06881, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0685 - val_loss: 0.0688
# Epoch 13/50
#
# Epoch 00013: val_loss did not improve from 0.06881
# 352/352 - 3s - loss: 0.0683 - val_loss: 0.0692
# Epoch 14/50
#
# Epoch 00014: val_loss improved from 0.06881 to 0.06871, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0681 - val_loss: 0.0687
# Epoch 15/50
#
# Epoch 00015: val_loss did not improve from 0.06871
# 352/352 - 3s - loss: 0.0680 - val_loss: 0.0688
# Epoch 16/50
#
# Epoch 00016: val_loss improved from 0.06871 to 0.06854, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0680 - val_loss: 0.0685
# Epoch 17/50
#
# Epoch 00017: val_loss improved from 0.06854 to 0.06814, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0676 - val_loss: 0.0681
# Epoch 18/50
#
# Epoch 00018: val_loss improved from 0.06814 to 0.06807, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0676 - val_loss: 0.0681
# Epoch 19/50
#
# Epoch 00019: val_loss improved from 0.06807 to 0.06794, saving model to denoising_model.h5
# 352/352 - 5s - loss: 0.0675 - val_loss: 0.0679
# Epoch 20/50
#
# Epoch 00020: val_loss improved from 0.06794 to 0.06785, saving model to denoising_model.h5
# 352/352 - 5s - loss: 0.0674 - val_loss: 0.0679
# Epoch 21/50
#
# Epoch 00021: val_loss improved from 0.06785 to 0.06777, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0674 - val_loss: 0.0678
# Epoch 22/50
#
# Epoch 00022: val_loss improved from 0.06777 to 0.06771, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0673 - val_loss: 0.0677
# Epoch 23/50
#
# Epoch 00023: val_loss did not improve from 0.06771
# 352/352 - 3s - loss: 0.0672 - val_loss: 0.0682
# Epoch 24/50
#
# Epoch 00024: val_loss improved from 0.06771 to 0.06748, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0671 - val_loss: 0.0675
# Epoch 25/50
#
# Epoch 00025: val_loss improved from 0.06748 to 0.06747, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0670 - val_loss: 0.0675
# Epoch 26/50
#
# Epoch 00026: val_loss did not improve from 0.06747
# 352/352 - 3s - loss: 0.0670 - val_loss: 0.0678
# Epoch 27/50
#
# Epoch 00027: val_loss did not improve from 0.06747
# 352/352 - 3s - loss: 0.0669 - val_loss: 0.0675
# Epoch 28/50
#
# Epoch 00028: val_loss improved from 0.06747 to 0.06742, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0668 - val_loss: 0.0674
# Epoch 29/50
#
# Epoch 00029: val_loss improved from 0.06742 to 0.06728, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0668 - val_loss: 0.0673
# Epoch 30/50
#
# Epoch 00030: val_loss improved from 0.06728 to 0.06714, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0667 - val_loss: 0.0671
# Epoch 31/50
#
# Epoch 00031: val_loss did not improve from 0.06714
# 352/352 - 3s - loss: 0.0667 - val_loss: 0.0696
# Epoch 32/50
#
# Epoch 00032: val_loss did not improve from 0.06714
# 352/352 - 3s - loss: 0.0667 - val_loss: 0.0684
# Epoch 33/50
#
# Epoch 00033: val_loss did not improve from 0.06714
# 352/352 - 3s - loss: 0.0666 - val_loss: 0.0672
# Epoch 34/50
#
# Epoch 00034: val_loss did not improve from 0.06714
# 352/352 - 3s - loss: 0.0666 - val_loss: 0.0672
# Epoch 35/50
#
# Epoch 00035: val_loss did not improve from 0.06714
# 352/352 - 3s - loss: 0.0665 - val_loss: 0.0673
# Epoch 36/50
#
# Epoch 00036: val_loss improved from 0.06714 to 0.06707, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0665 - val_loss: 0.0671
# Epoch 37/50
#
# Epoch 00037: val_loss did not improve from 0.06707
# 352/352 - 3s - loss: 0.0664 - val_loss: 0.0686
# Epoch 38/50
#
# Epoch 00038: val_loss improved from 0.06707 to 0.06692, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0664 - val_loss: 0.0669
# Epoch 39/50
#
# Epoch 00039: val_loss did not improve from 0.06692
# 352/352 - 3s - loss: 0.0663 - val_loss: 0.0672
# Epoch 40/50
#
# Epoch 00040: val_loss did not improve from 0.06692
# 352/352 - 3s - loss: 0.0664 - val_loss: 0.0678
# Epoch 41/50
#
# Epoch 00041: val_loss improved from 0.06692 to 0.06685, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0663 - val_loss: 0.0668
# Epoch 42/50
#
# Epoch 00042: val_loss did not improve from 0.06685
# 352/352 - 3s - loss: 0.0663 - val_loss: 0.0675
# Epoch 43/50
#
# Epoch 00043: val_loss did not improve from 0.06685
# 352/352 - 3s - loss: 0.0662 - val_loss: 0.0675
# Epoch 44/50
#
# Epoch 00044: val_loss did not improve from 0.06685
# 352/352 - 3s - loss: 0.0662 - val_loss: 0.0671
# Epoch 45/50
#
# Epoch 00045: val_loss improved from 0.06685 to 0.06674, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0662 - val_loss: 0.0667
# Epoch 46/50
#
# Epoch 00046: val_loss improved from 0.06674 to 0.06669, saving model to denoising_model.h5
# 352/352 - 4s - loss: 0.0661 - val_loss: 0.0667
# Epoch 47/50
#
# Epoch 00047: val_loss did not improve from 0.06669
# 352/352 - 3s - loss: 0.0661 - val_loss: 0.0669
# Epoch 48/50
#
# Epoch 00048: val_loss did not improve from 0.06669
# 352/352 - 3s - loss: 0.0661 - val_loss: 0.0678
# Epoch 49/50
#
# Epoch 00049: val_loss improved from 0.06669 to 0.06663, saving model to denoising_model.h5
# 352/352 - 3s - loss: 0.0661 - val_loss: 0.0666
# Epoch 50/50
#
# Epoch 00050: val_loss did not improve from 0.06663
# 352/352 - 3s - loss: 0.0661 - val_loss: 0.0670

# %%
# load best performance model
from keras.models import load_model
autoencoder = load_model('denoising_model.h5')
autoencoder.summary()
# Out:
# Model: "Denoising_Model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 28, 28, 32)        320
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 28, 28, 32)        128
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 14, 14, 32)        128
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 32)          9248
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 7, 7, 32)          128
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 32)        9248
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 14, 14, 32)        128
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 28, 28, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 1)         289
# =================================================================
# Total params: 28,865
# Trainable params: 28,609
# Non-trainable params: 256
# _________________________________________________________________

# %%
def visualize_data(data, row, column):
    data = data.reshape(data.shape[0], 28,28)
    count = 0
    fig, axes = plt.subplots(row, column, figsize = (16,4))
    for i in range(row):
        for j in range(column):
            axes[i,j].imshow(data[count], cmap = 'gray')
            count+=1

# %%
visualize_data(X_test_noise[:20], 2,10)

# %%
pred = autoencoder.predict(X_test_noise[:20])
pred.shape
# Out:
# (20, 28, 28, 1)

# %%
visualize_data(pred, 2, 10)
